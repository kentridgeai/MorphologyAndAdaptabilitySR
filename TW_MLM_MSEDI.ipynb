# %%
from TW_MLM_MSEDI import *

# %%
NN_MSEDI("0.7*X**3-1.7*X",-3,3, num_points=100)
# Out:
# RNG_STATE:0
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0     9.47       3.0891e+83        7        0.0103929       0.00540411      0.00s
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    1     6.03          48.3996        9          1.30112          1.49176      0.90s
#    2     8.10          417.747       10          0.23596         0.208561      1.25s
#    3     9.85          736.538       10         0.225743         0.300516      0.53s
#    4     9.90          8.99305       10         0.226513         0.293578      0.00s
# ...
